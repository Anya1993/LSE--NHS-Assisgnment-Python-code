# %% [markdown]
# ### LSE Data Analytics Online Career Accelerator
#
# # Course 2: Data Analytics using Python

# %% [markdown]
# ## Assignment: Diagnostic Analysis using Python
#
# You’ll be working with real-world data to address a problem faced by the National Health Service (NHS). The analysis will require you to utilise Python to explore the available data, create visualisations to identify trends, and extract meaningful insights to inform decision-making.

# %% [markdown]
# ### A note for students using this template
# This Jupyter Notebook is a template you can use to complete the Course 2 assignment: Diagnostic Analysis using Python.
#
# Keep in mind:
# - You are **not required** to use this template to complete the assignment.
# - If you decide to use this template for your assignment, make a copy of the notebook and save it using the assignment naming convention: **LastName_FirstName_DA201_Assignment_Notebook.ipynb**.
# - The workflow suggested in this template follows the Assignment Activities throughout the course.
# - Refer to the guidance on the Assignment Activity pages for specific details.
# - The markup and comments in this template identify the key elements you need to complete before submitting the assignment.
# - Make this notebook your own by adding your process notes and rationale using markdown, add links, screenshots, or images to support your analysis, refine or clarify the comments, and change the workflow to suit your process.
# - All elements should be functional and visible in your Notebook.
# - After completing each Assignment Activity, back up your work to a safe location. This would allow you to revert to a previous state in the case of making a mistake in the code, or deleting a section by mistake. (A simple way of doing this is to save or mail a compressed version at frequent intervals).
#
#  > ***Markdown*** Remember to change cell types to `Markdown`. You can review [Markdown basics](https://docs.github.com/en/get-started/writing-on-github/getting-started-with-writing-and-formatting-on-github/basic-writing-and-formatting-syntax) to find out how to add formatted text, links, and images to your notebook.

# %% [markdown]
# #

# %% [markdown]
# # Assignment activity 1

# %% [markdown]
# ### Plan your approach

# %% [markdown]
# # Assignment activity 2

# %% [markdown]
# ### Prepare your workstation

# %%
# Import the necessary libraries.
import pandas as pd
import numpy as np
from datetime import datetime
import seaborn as sns
import matplotlib.pyplot as plt



# Optional - Ignore warnings.
import warnings
warnings.filterwarnings('ignore')

# %%
# Import and sense-check the actual_duration.csv data set as ad.
ad = pd.read_csv('actual_duration.csv')

# View the DataFrame.
print(ad.head(5))
# Out:
#   sub_icb_location_code sub_icb_location_ons_code  \
# 0                   00L                 E38000130
# 1                   00L                 E38000130
# 2                   00L                 E38000130
# 3                   00L                 E38000130
# 4                   00L                 E38000130
#
#                         sub_icb_location_name icb_ons_code region_ons_code  \
# 0  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 1  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 2  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 3  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 4  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
#
#   appointment_date         actual_duration  count_of_appointments
# 0        01-Dec-21           31-60 Minutes                    364
# 1        01-Dec-21           21-30 Minutes                    619
# ...

# %%
# Import and sense-check the national_categories.xlsx data set as nc.
nc = pd.read_excel('national_categories.xlsx')                                 

# View the DataFrame.
print(nc.head(5))
# Out:
#   appointment_date icb_ons_code                       sub_icb_location_name  \
# 0       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 1       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 2       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 3       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 4       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
#
#         service_setting            context_type  \
# 0  Primary Care Network  Care Related Encounter
# 1                 Other  Care Related Encounter
# 2      General Practice  Care Related Encounter
# 3      General Practice  Care Related Encounter
# 4      General Practice  Care Related Encounter
#
#                         national_category  count_of_appointments  \
# 0  Patient contact during Care Home Round                      3
# 1                         Planned Clinics                      7
# ...

# %%
# Import and sense-check the appointments_regional.csv data set as ar.
ar = pd.read_csv('appointments_regional.csv')

# View the DataFrame.
ar.head(5)
# Out:
#   icb_ons_code appointment_month appointment_status hcp_type appointment_mode  \
# 0    E54000034           2020-01           Attended       GP     Face-to-Face
# 1    E54000034           2020-01           Attended       GP     Face-to-Face
# 2    E54000034           2020-01           Attended       GP     Face-to-Face
# 3    E54000034           2020-01           Attended       GP     Face-to-Face
# 4    E54000034           2020-01           Attended       GP     Face-to-Face
#
#   time_between_book_and_appointment  count_of_appointments
# 0                             1 Day                   8107
# 1                    15  to 21 Days                   6791
# 2                       2 to 7 Days                  20686
# 3                    22  to 28 Days                   4268
# 4                     8  to 14 Days                  11971

# %%
ad.info
# Out:
# <bound method DataFrame.info of        sub_icb_location_code sub_icb_location_ons_code  \
# 0                        00L                 E38000130
# 1                        00L                 E38000130
# 2                        00L                 E38000130
# 3                        00L                 E38000130
# 4                        00L                 E38000130
# ...                      ...                       ...
# 137788                 X2C4Y                 E38000254
# 137789                 X2C4Y                 E38000254
# 137790                 X2C4Y                 E38000254
# 137791                 X2C4Y                 E38000254
# 137792                 X2C4Y                 E38000254
#
#                              sub_icb_location_name icb_ons_code  \
# 0       NHS North East and North Cumbria ICB - 00L    E54000050
# 1       NHS North East and North Cumbria ICB - 00L    E54000050
# 2       NHS North East and North Cumbria ICB - 00L    E54000050
# ...

# %%
# Determine whether there are missing values on ad.
ad.isnull().sum()
# Out:
# sub_icb_location_code        0
# sub_icb_location_ons_code    0
# sub_icb_location_name        0
# icb_ons_code                 0
# region_ons_code              0
# appointment_date             0
# actual_duration              0
# count_of_appointments        0
# dtype: int64

# %%
# Determine whether there are missing values on nc.
nc.isnull().sum()
# Out:
# appointment_date         0
# icb_ons_code             0
# sub_icb_location_name    0
# service_setting          0
# context_type             0
# national_category        0
# count_of_appointments    0
# appointment_month        0
# dtype: int64

# %%
# Determine whether there are missing values on ar.
ar.isnull().sum()
# Out:
# icb_ons_code                         0
# appointment_month                    0
# appointment_status                   0
# hcp_type                             0
# appointment_mode                     0
# time_between_book_and_appointment    0
# count_of_appointments                0
# dtype: int64

# %%
# Determine whether there are duplicate values on ad.
ad_duplicates=ad.duplicated().sum()
ad_duplicates
# Out:
# 0

# %%
# Determine whether there are duplicate values on nc.
nc_duplicates=nc.duplicated().sum()
nc_duplicates
# Out:
# 0

# %%
ar.columns
# Out:
# Index(['icb_ons_code', 'appointment_month', 'appointment_status', 'hcp_type',
#        'appointment_mode', 'time_between_book_and_appointment',
#        'count_of_appointments'],
#       dtype='object')

# %%
# Determine whether there are duplicate values on ar.
ar_duplicates= ar.duplicated().sum()
ar_duplicates
# Out:
# 21604

# %%
# Show all duplicate rows on ar
ar_duplicates1= ar[ar.duplicated()]
ar_duplicates1
# Out:
#        icb_ons_code appointment_month appointment_status hcp_type  \
# 19292     E54000044           2020-01           Attended       GP
# 19308     E54000044           2020-01           Attended       GP
# 19374     E54000044           2020-01                DNA       GP
# 19417     E54000044           2020-01                DNA  Unknown
# 19419     E54000044           2020-01                DNA  Unknown
# ...             ...               ...                ...      ...
# 596809    E54000050           2022-06            Unknown  Unknown
# 596812    E54000050           2022-06            Unknown  Unknown
# 596814    E54000050           2022-06            Unknown  Unknown
# 596817    E54000050           2022-06            Unknown  Unknown
# 596820    E54000050           2022-06            Unknown  Unknown
#
#        appointment_mode time_between_book_and_appointment  \
# 19292        Home Visit            Unknown / Data Quality
# ...

# %%
# Correct ar['appointment_monthe'] to appointment_month
ar = ar.rename(columns={'appointment_monthe': 'appointment_month'})
ar
# Out:
#        icb_ons_code appointment_month appointment_status hcp_type  \
# 0         E54000034           2020-01           Attended       GP
# 1         E54000034           2020-01           Attended       GP
# 2         E54000034           2020-01           Attended       GP
# 3         E54000034           2020-01           Attended       GP
# 4         E54000034           2020-01           Attended       GP
# ...             ...               ...                ...      ...
# 596816    E54000050           2022-06            Unknown  Unknown
# 596817    E54000050           2022-06            Unknown  Unknown
# 596818    E54000050           2022-06            Unknown  Unknown
# 596819    E54000050           2022-06            Unknown  Unknown
# 596820    E54000050           2022-06            Unknown  Unknown
#
#        appointment_mode time_between_book_and_appointment  \
# 0          Face-to-Face                             1 Day
# ...

# %%
# Checking if is there any typo on the columns
ad ['sub_icb_location_code'].value_counts()
ad ['sub_icb_location_ons_code'].value_counts()
ad ['sub_icb_location_name'].value_counts()
ad ['icb_ons_code'].value_counts()
# Out:
# icb_ons_code
# E54000057    12668
# E54000008    10636
# E54000050     9938
# E54000048     9808
# E54000051     7973
# E54000010     7208
# E54000054     6681
# E54000026     6653
# E54000061     4471
# E54000053     4339
# E54000015     4103
# E54000044     3930
# E54000025     3903
# E54000023     3893
# E54000060     2561
# E54000042     2513
# E54000032     1484
# E54000024     1484
# E54000029     1484
# E54000022     1484
# E54000027     1484
# E54000037     1483
# E54000062     1480
# E54000055     1477
# E54000056     1471
# E54000041     1454
# E54000013     1445
# E54000052     1443
# E54000028     1435
# E54000034     1421
# E54000036     1420
# E54000058     1395
# E54000059     1392
# E54000011     1385
# E54000039     1365
# E54000031     1359
# E54000030     1358
# E54000019     1311
# E54000043     1294
# E54000018     1258
# E54000040     1242
# E54000038     1207
# Name: count, dtype: int64

# %%
# Determine the metadata of the data set.
ad.describe
ad.shape
# Out:
# (137793, 8)

# %%
# Determine the descriptive statistics of the data set.
print(ad.describe())
# Out:
#        count_of_appointments
# count          137793.000000
# mean             1219.080011
# std              1546.902956
# min                 1.000000
# 25%               194.000000
# 50%               696.000000
# 75%              1621.000000
# max             15400.000000

# %%
# Determine whether there are missing values.
ar.isnull().sum()
# Out:
# icb_ons_code                         0
# appointment_month                    0
# appointment_status                   0
# hcp_type                             0
# appointment_mode                     0
# time_between_book_and_appointment    0
# count_of_appointments                0
# dtype: int64

# %%
# Determine the metadata of the data set.
ar.shape
# Out:
# (596821, 7)

# %%
# Determine the descriptive statistics of the data set.
print(ar.describe())
# Out:
#        count_of_appointments
# count          596821.000000
# mean             1244.601857
# std              5856.887042
# min                 1.000000
# 25%                 7.000000
# 50%                47.000000
# 75%               308.000000
# max            211265.000000

# %%
# Determine whether there are missing values.
nc.isnull().sum()
# Out:
# appointment_date         0
# icb_ons_code             0
# sub_icb_location_name    0
# service_setting          0
# context_type             0
# national_category        0
# count_of_appointments    0
# appointment_month        0
# dtype: int64

# %%
# Determine the metadata of the data set.
nc.describe
# Out:
# <bound method NDFrame.describe of        appointment_date icb_ons_code  \
# 0            2021-08-02    E54000050
# 1            2021-08-02    E54000050
# 2            2021-08-02    E54000050
# 3            2021-08-02    E54000050
# 4            2021-08-02    E54000050
# ...                 ...          ...
# 817389       2022-06-30    E54000054
# 817390       2022-06-30    E54000054
# 817391       2022-06-30    E54000054
# 817392       2022-06-30    E54000054
# 817393       2022-06-30    E54000054
#
#                              sub_icb_location_name            service_setting  \
# 0       NHS North East and North Cumbria ICB - 00L       Primary Care Network
# 1       NHS North East and North Cumbria ICB - 00L                      Other
# 2       NHS North East and North Cumbria ICB - 00L           General Practice
# 3       NHS North East and North Cumbria ICB - 00L           General Practice
# 4       NHS North East and North Cumbria ICB - 00L           General Practice
# ...

# %%
nc.shape
# Out:
# (817394, 8)

# %%
# Determine the descriptive statistics of the data set.
print(nc.describe())
# Out:
#                     appointment_date  count_of_appointments
# count                         817394          817394.000000
# mean   2022-01-16 00:50:35.860796160             362.183684
# min              2021-08-01 00:00:00               1.000000
# 25%              2021-10-25 00:00:00               7.000000
# 50%              2022-01-18 00:00:00              25.000000
# 75%              2022-04-07 00:00:00             128.000000
# max              2022-06-30 00:00:00           16590.000000
# std                              NaN            1084.576600

# %% [markdown]
# ### Explore the data set

# %% [markdown]
# **Question 1:** How many locations are there in the data set?

# %%
# Determine the number of locations.
nc['sub_icb_location_name'].value_counts()
# Out:
# sub_icb_location_name
# NHS North West London ICB - W2U3Z              13007
# NHS Kent and Medway ICB - 91Q                  12637
# NHS Devon ICB - 15N                            12526
# NHS Hampshire and Isle Of Wight ICB - D9Y0V    12171
# NHS North East London ICB - A3A8R              11837
#                                                ...
# NHS North East and North Cumbria ICB - 00N      4210
# NHS Lancashire and South Cumbria ICB - 02G      4169
# NHS Cheshire and Merseyside ICB - 01V           3496
# NHS Cheshire and Merseyside ICB - 01T           3242
# NHS Greater Manchester ICB - 00V                2170
# Name: count, Length: 106, dtype: int64

# %% [markdown]
# **Question 2:** What are the five locations with the highest number of appointments?

# %%
# Determine the top five locations based on record count.
numers_of_appointments_per_location =nc.pivot_table(
    values = 'count_of_appointments',
    index = 'sub_icb_location_name',
    aggfunc ='sum')

# Sort the datafrom from DESC by count_of_appointments
numers_of_appointments_per_location =numers_of_appointments_per_location.sort_values(by='count_of_appointments', ascending =False)

numers_of_appointments_per_location.head(5)
# Out:
#                                              count_of_appointments
# sub_icb_location_name
# NHS North West London ICB - W2U3Z                         12142390
# NHS North East London ICB - A3A8R                          9588891
# NHS Kent and Medway ICB - 91Q                              9286167
# NHS Hampshire and Isle Of Wight ICB - D9Y0V                8288102
# NHS South East London ICB - 72Q                            7850170

# %%
# Determine the top five region based on record count.
numers_of_appointments_per_region =location_nc.pivot_table(
    values = 'count_of_appointments',
    index = 'REGION_NAME',
    aggfunc ='sum')

# Sort the datafrom from DESC by count_of_appointments
numers_of_appointments_per_region =numers_of_appointments_per_region.sort_values(by='count_of_appointments', ascending =False)

numers_of_appointments_per_region.head(5)
# Out:
#                           count_of_appointments
# REGION_NAME
# Midlands                               57352329
# North East and Yorkshire               47915966
# South East                             45003534
# London                                 43484439
# North West                             35865459

# %% [markdown]
# **Question 3:** How many service settings, context types, national categories, and appointment statuses are there?

# %%
# Determine the number of service settings.
nc['service_setting'].value_counts()
# Out:
# service_setting
# General Practice             359274
# Primary Care Network         183790
# Other                        138789
# Extended Access Provision    108122
# Unmapped                      27419
# Name: count, dtype: int64

# %%
# Determine the number of context types.
nc['context_type'].value_counts()
# Out:
# context_type
# Care Related Encounter    700481
# Inconsistent Mapping       89494
# Unmapped                   27419
# Name: count, dtype: int64

# %%
# Determine the number of national categories.
nc['national_category'].value_counts()
# Out:
# national_category
# Inconsistent Mapping                                                   89494
# General Consultation Routine                                           89329
# General Consultation Acute                                             84874
# Planned Clinics                                                        76429
# Clinical Triage                                                        74539
# Planned Clinical Procedure                                             59631
# Structured Medication Review                                           44467
# Service provided by organisation external to the practice              43095
# Home Visit                                                             41850
# Unplanned Clinical Activity                                            40415
# Patient contact during Care Home Round                                 28795
# Unmapped                                                               27419
# ...

# %%
# Determine the number of appointment statuses.
ar['appointment_status'].value_counts()
# Out:
# appointment_status
# Attended    232137
# Unknown     201324
# DNA         163360
# Name: count, dtype: int64

# %% [markdown]
# #

# %% [markdown]
# # Assignment activity 3

# %% [markdown]
# ### Continue to explore the data and search for answers to more specific questions posed by the NHS.

# %% [markdown]
# **Question 1:** Between what dates were appointments scheduled?

# %%
# View the first five rows of appointment_date for the ad DataFrame to determine the date format.
ad['appointment_date'].head(5)
# Out:
# 0    01-Dec-21
# 1    01-Dec-21
# 2    01-Dec-21
# 3    01-Dec-21
# 4    01-Dec-21
# Name: appointment_date, dtype: object

# %%
# View the first five rows of appointment_date for the nc DataFrame to determine the date format.
nc['appointment_date'].head(5)
# Out:
# 0   2021-08-02
# 1   2021-08-02
# 2   2021-08-02
# 3   2021-08-02
# 4   2021-08-02
# Name: appointment_date, dtype: datetime64[ns]

# %%
# Import datatime library 
import pandas as pd
from datetime import datetime 
# Convert to datetime obviously if not already in correct format
ad['appointment_date'] = pd.to_datetime(ad['appointment_date'])
ad['year'] = ad['appointment_date'].dt.year 
ad['month'] = ad['appointment_date'].dt.month_name()  
# View the output
print(ad['appointment_date'])
# Out:
# 0        2021-12-01
# 1        2021-12-01
# 2        2021-12-01
# 3        2021-12-01
# 4        2021-12-01
#             ...
# 137788   2022-06-30
# 137789   2022-06-30
# 137790   2022-06-30
# 137791   2022-06-30
# 137792   2022-06-30
# Name: appointment_date, Length: 137793, dtype: datetime64[ns]

# %%
# Convert to datetime obviously if not already in correct format
ar['appointment_month'] = pd.to_datetime(ar['appointment_month'])
ar['year'] = ar['appointment_month'].dt.year 
ar['month'] = ar['appointment_month'].dt.month_name() 
# View the output
print(ar['appointment_month'])
# Out:
# 0        2020-01-01
# 1        2020-01-01
# 2        2020-01-01
# 3        2020-01-01
# 4        2020-01-01
#             ...
# 596816   2022-06-01
# 596817   2022-06-01
# 596818   2022-06-01
# 596819   2022-06-01
# 596820   2022-06-01
# Name: appointment_month, Length: 596821, dtype: datetime64[ns]

# %%
# Change the date format of ar['appointment_date'].
ar['appointment_month'] = ar['appointment_month'].dt.strftime("%m/%d/%Y")
# View the DateFrame.
ar['appointment_month'].head(5)
# Out:
# 0    01/01/2020
# 1    01/01/2020
# 2    01/01/2020
# 3    01/01/2020
# 4    01/01/2020
# Name: appointment_month, dtype: object

# %%
# Change the date format of nc['appointment_date'].
nc['appointment_date'] = pd.to_datetime(nc['appointment_date'])
nc['appointment_date'] = nc['appointment_date'].dt.strftime("%m/%d/%Y")
# View the DateFrame.
nc['appointment_date'].head(5)
# Out:
# 0    08/02/2021
# 1    08/02/2021
# 2    08/02/2021
# 3    08/02/2021
# 4    08/02/2021
# Name: appointment_date, dtype: object

# %%
# Determine the maximum and minimum dates in the ad DataFrame.
# Use appropriate docstrings.
ad['appointment_date'].agg(['min', 'max'])
# Out:
# min   2021-12-01
# max   2022-06-30
# Name: appointment_date, dtype: datetime64[ns]

# %%
# Determine the maximum and minimum dates in the ad DataFrame.
# Use appropriate docstrings.
ar['appointment_month'].agg(['min', 'max'])
# Out:
# min    01/01/2020
# max    12/01/2021
# Name: appointment_month, dtype: object

# %%
# Determine the minimum and maximum dates in the nc DataFrame.
# Use appropriate docstrings.
nc['appointment_date'].agg(['min', 'max'])
# Out:
# min    01/01/2022
# max    12/31/2021
# Name: appointment_date, dtype: object

# %% [markdown]
# **Question 2:** Which service setting was the most popular for NHS North West London from 1 January to 1 June 2022?

# %%
# For each of these service settings, determine the number of records available for the period and the location. 
# Count records per service setting and location

# Filter by location
nc_subset = nc[nc['sub_icb_location_name'] == 'NHS North West London ICB - W2U3Z']

# Define date range
start_date = '2022-01-01'
end_date = '2022-06-01'

# Apply date filter
dates_filter = nc_subset[
    (nc_subset['appointment_date'] >= start_date) & 
    (nc_subset['appointment_date'] <= end_date)]

# Group by service_setting and sum appointments
ss_cnt = dates_filter.groupby('service_setting', as_index=False)['count_of_appointments'].sum()

# Rename column for clarity
ss_cnt = ss_cnt.rename(columns={'count_of_appointments': 'total_appointments'})

# View result
print(ss_cnt.head())
# Out:
# Empty DataFrame
# Columns: [service_setting, total_appointments]
# Index: []

# %% [markdown]
# **Question 3:** Which month had the highest number of appointments?

# %%
nc['appointment_date'] = pd.to_datetime(nc['appointment_date'], errors='coerce')

# Extract year and month from the appointment_date
nc['appointment_year'] = nc['appointment_date'].dt.year
nc['appointment_month'] = nc['appointment_date'].dt.month

# Number of appointments per month == sum of count_of_appointments by month.
# Use the groupby() and sort_values() functions.
monthly_appointments = nc.groupby(['appointment_year', 'appointment_month'])['count_of_appointments'].sum()


# Display the result
monthly_appointments
# Out:
# appointment_year  appointment_month
# 2021              8                    23852171
#                   9                    28522501
#                   10                   30303834
#                   11                   30405070
#                   12                   25140776
# 2022              1                    25635474
#                   2                    25355260
#                   3                    29595038
#                   4                    23913060
#                   5                    27495508
#                   6                    25828078
# Name: count_of_appointments, dtype: int64

# %% [markdown]
# **Question 4:** What was the total number of records per month?

# %%
# Total number of records per month.
monthly_appointments = nc.groupby(['appointment_year', 'appointment_month'])['count_of_appointments'].sum()
monthly_appointments_df = monthly_appointments.reset_index()

# View the result
print(monthly_appointments_df)
# Out:
#     appointment_year  appointment_month  count_of_appointments
# 0               2021                  8               23852171
# 1               2021                  9               28522501
# 2               2021                 10               30303834
# 3               2021                 11               30405070
# 4               2021                 12               25140776
# 5               2022                  1               25635474
# 6               2022                  2               25355260
# 7               2022                  3               29595038
# 8               2022                  4               23913060
# 9               2022                  5               27495508
# 10              2022                  6               25828078

# %% [markdown]
# #

# %% [markdown]
# # Assignment activity 4

# %% [markdown]
# ### Create visualisations and identify possible monthly and seasonal trends in the data.

# %%
# Import the necessary libraries.
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Set figure size.
sns.set(rc={'figure.figsize':(15, 12)})

# Set the plot style as white.
sns.set_style('white')

# %% [markdown]
# ### Objective 1
# Create three visualisations indicating the number of appointments per month for service settings, context types, and national categories.

# %%
# After mapping, convert to string 
nc['appointment_month'] = nc['appointment_month'].astype(str)

# View the result
print(nc.head())
# Out:
#   appointment_date icb_ons_code                       sub_icb_location_name  \
# 0       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 1       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 2       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 3       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 4       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
#
#         service_setting            context_type  \
# 0  Primary Care Network  Care Related Encounter
# 1                 Other  Care Related Encounter
# 2      General Practice  Care Related Encounter
# 3      General Practice  Care Related Encounter
# 4      General Practice  Care Related Encounter
#
#                         national_category  count_of_appointments  \
# 0  Patient contact during Care Home Round                      3
# 1                         Planned Clinics                      7
# ...

# %% [markdown]
# **Service settings:**

# %%
# Aggregate on monthly level and determine the sum of records per month.
monthly_service_setting = nc.groupby(['service_setting','appointment_month'])['count_of_appointments'].sum().reset_index(name='count_of_appointments')  
monthly_service_setting
# Out:
#               service_setting appointment_month  count_of_appointments
# 0   Extended Access Provision                 1                 186375
# 1   Extended Access Provision                10                 209539
# 2   Extended Access Provision                11                 207577
# 3   Extended Access Provision                12                 173504
# 4   Extended Access Provision                 2                 196627
# 5   Extended Access Provision                 3                 231905
# 6   Extended Access Provision                 4                 192284
# 7   Extended Access Provision                 5                 220511
# 8   Extended Access Provision                 6                 209652
# 9   Extended Access Provision                 8                 160927
# 10  Extended Access Provision                 9                 187906
# 11           General Practice                 1               23583053
# ...

# %%
# Aggregate on monthly level and determine the sum of records per month.
monthly_service_setting = nc.groupby(['service_setting','appointment_month'])['count_of_appointments'].sum().reset_index(name='count_of_appointments')           

# View the result
print(monthly_service_setting)
# Create a lineplot.
plt.figure(figsize=(12, 6))  # Set plot size

sns.lineplot(x='appointment_month', y='count_of_appointments', data=monthly_service_setting, hue='service_setting')

plt.title("Service Settings Over Time")
plt.xticks(rotation=45)  
plt.xlabel("Months")  
plt.ylabel("Count_of_Service_settings")  
plt.legend(title="Service Setting"  , bbox_to_anchor=(1,1)) 
plt.savefig("Service Settings Over Time.png")
plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)
# Out:
#               service_setting appointment_month  count_of_appointments
# 0   Extended Access Provision                 1                 186375
# 1   Extended Access Provision                10                 209539
# 2   Extended Access Provision                11                 207577
# 3   Extended Access Provision                12                 173504
# 4   Extended Access Provision                 2                 196627
# 5   Extended Access Provision                 3                 231905
# 6   Extended Access Provision                 4                 192284
# 7   Extended Access Provision                 5                 220511
# 8   Extended Access Provision                 6                 209652
# 9   Extended Access Provision                 8                 160927
# 10  Extended Access Provision                 9                 187906
# 11           General Practice                 1               23583053
# ...

# %% [markdown]
# **Context types:**

# %%
# Create a separate data set that can be used in future weeks. 
context_type_counts = nc.groupby(['context_type', 'appointment_month']).size().reset_index(name='count')
context_type_counts
# Out:
#               context_type appointment_month  count
# 0   Care Related Encounter                 1  61629
# 1   Care Related Encounter                10  62937
# 2   Care Related Encounter                11  66452
# 3   Care Related Encounter                12  62084
# 4   Care Related Encounter                 2  61628
# 5   Care Related Encounter                 3  71304
# 6   Care Related Encounter                 4  60189
# 7   Care Related Encounter                 5  66783
# 8   Care Related Encounter                 6  64041
# 9   Care Related Encounter                 8  59604
# 10  Care Related Encounter                 9  63830
# 11    Inconsistent Mapping                 1   7861
# 12    Inconsistent Mapping                10   8432
# 13    Inconsistent Mapping                11   8549
# 14    Inconsistent Mapping                12   8028
# 15    Inconsistent Mapping                 2   7826
# 16    Inconsistent Mapping                 3   8883
# ...

# %%
# Create a separate data set that can be used in future weeks. 
context_type_counts = nc.groupby(['context_type', 'appointment_month']).size().reset_index(name='count')

# View output.
context_type_counts.head(5)

# Plot the appointments over the available date range, and review the context types for months.
# Create a lineplot.
# Ensure appointment_month is a proper datetime format for plotting


# Set figure size
plt.figure(figsize=(12, 6))

# Create lineplot
sns.lineplot(
    x='appointment_month', 
    y='count', 
    data=context_type_counts, 
    hue='context_type', 
    marker='o'  )

# Formatting
plt.title("Context Type Over Time")
plt.xticks(rotation=45)
plt.xlabel("Month")
plt.ylabel("Number of Appointments")
plt.legend(title="Context Type") 
plt.grid(True)  
plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)

# Show plot
plt.show()
plt.savefig("Context Type Over Time.png", dpi =300)

# %% [markdown]
# **National categories:**

# %%
# Create a separate data set that can be used in future weeks. 
numbers_of_appointments_per_national_categories =nc.pivot_table(
    values = 'count_of_appointments',
    index = ['national_category', 'appointment_month'],
    aggfunc ='sum').reset_index().sort_values(by='count_of_appointments', ascending=False)

# View output.
numbers_of_appointments_per_national_categories.head(10)
# Out:
#                national_category appointment_month  count_of_appointments
# 49  General Consultation Routine                 3               10074249
# 46  General Consultation Routine                11                9778682
# 51  General Consultation Routine                 5                9320538
# 45  General Consultation Routine                10                9256788
# 54  General Consultation Routine                 9                9060243
# 52  General Consultation Routine                 6                8691384
# 44  General Consultation Routine                 1                8645563
# 48  General Consultation Routine                 2                8565715
# 47  General Consultation Routine                12                8123938
# 50  General Consultation Routine                 4                7998377

# %%
# Plot the appointments over the available date range, and review the national categories for months.
# Create a lineplot.
# Set figure size
plt.figure(figsize=(12, 12))

# Create lineplot
sns.lineplot(
    x='appointment_month', 
    y='count_of_appointments', 
    data=numbers_of_appointments_per_national_categories, 
    hue='national_category', 
    marker='o'  
)

# Formatting
plt.title("National category Over Time")
plt.xticks(rotation=45)
plt.xlabel("Month")
plt.ylabel("count_of_appointments")
plt.legend(title="National Category", bbox_to_anchor=(1.85,1)) 
plt.grid(True)  
plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)

# Show plot
plt.show()

# %%
# Plot the appointments over the available date range, and review the national categories for months.
# Create a barplot.
# Set figure size
plt.figure(figsize=(12, 12))

# Create lineplot
sns.barplot(
    x='appointment_month', 
    y='count_of_appointments', 
    data=numbers_of_appointments_per_national_categories, 
    hue='national_category')

# Formatting
plt.title("National category Over Time")
plt.xticks(rotation=45)
plt.xlabel("Month")
plt.ylabel("count_of_appointments")
plt.legend(title="National Category", bbox_to_anchor=(1.85,1)) 
plt.grid(True)  
plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)

# Show plot
plt.show()

# %%
# Extract the month and year from 'appointment_date'
ad['appointment_year_month'] = ad['appointment_date'].dt.to_period('M')

# Aggregate on actual duration and determine the sum of records per month.
monthly_actual_duration = ad.groupby(['actual_duration','appointment_year_month'])['count_of_appointments'].sum().sort_values(ascending=False)
monthly_actual_duration_df = monthly_actual_duration.reset_index()

# View the result
print(monthly_actual_duration_df)
# Out:
#            actual_duration appointment_year_month  count_of_appointments
# 0   Unknown / Data Quality                2022-03                6472072
# 1   Unknown / Data Quality                2022-05                6059540
# 2   Unknown / Data Quality                2022-06                5676225
# 3   Unknown / Data Quality                2022-01                5627141
# 4   Unknown / Data Quality                2022-02                5588440
# 5   Unknown / Data Quality                2021-12                5579512
# 6             6-10 Minutes                2022-03                5489184
# 7   Unknown / Data Quality                2022-04                5281156
# 8             6-10 Minutes                2022-05                5033645
# 9             6-10 Minutes                2022-01                4778719
# 10            6-10 Minutes                2022-06                4726440
# 11            6-10 Minutes                2022-02                4695914
# ...

# %% [markdown]
# ### Objective 2
# Create four visualisations indicating the number of appointments for service setting per season. The seasons are summer (June to August 2021), autumn (September to November 2021), winter (December to February 2022), and spring (March to May 2022).

# %% [markdown]
# **Summer (June to August 2021):**

# %%
# Filter data for summer months (June to August 2021)
summer_data = nc[(nc['appointment_date'] >= '2021-06-01') & 
                 (nc['appointment_date'] <= '2021-08-31')]
summer_data
# Out:
#        appointment_date icb_ons_code  \
# 0            2021-08-02    E54000050
# 1            2021-08-02    E54000050
# 2            2021-08-02    E54000050
# 3            2021-08-02    E54000050
# 4            2021-08-02    E54000050
# ...                 ...          ...
# 808176       2021-08-31    E54000054
# 808177       2021-08-31    E54000054
# 808178       2021-08-31    E54000054
# 808179       2021-08-31    E54000054
# 808180       2021-08-31    E54000054
#
#                              sub_icb_location_name       service_setting  \
# 0       NHS North East and North Cumbria ICB - 00L  Primary Care Network
# 1       NHS North East and North Cumbria ICB - 00L                 Other
# 2       NHS North East and North Cumbria ICB - 00L      General Practice
# 3       NHS North East and North Cumbria ICB - 00L      General Practice
# 4       NHS North East and North Cumbria ICB - 00L      General Practice
# ...

# %%
# Create a separate data set that can be used in future weeks. 

# Filter data for summer months (June to August 2021)
summer_data = nc[(nc['appointment_date'] >= '2021-06-01') & 
                 (nc['appointment_date'] <= '2021-08-31')]


# Aggregate the sum of 'count_of_appointments' by 'appointment_month' 
numbers_of_appointments_summer_2021 = summer_data.pivot_table(
    values='count_of_appointments',
    index='appointment_month',
    aggfunc='sum').reset_index()

# View the result
numbers_of_appointments_summer_2021.head(5)

# Look at June to August 2021 in more detail to allow a closer look.

# Create barplot
plt.figure(figsize=(8, 5))

sns.barplot(
    x='appointment_month', 
    y='count_of_appointments', 
    data=numbers_of_appointments_summer_2021)

# Formatting
plt.title("Appointments in Summer 2021")
plt.xticks(rotation=45)
plt.xlabel("Month")
plt.ylabel("Total appointments in 10s of millions")
plt.grid(True)  

# Show plot
plt.show()

# %% [markdown]
# **Autumn (September to November 2021):**

# %%
# Look at September to November 2021 in more detail to allow a closer look.
autumn_data = nc[(nc['appointment_date'] >= '2021-09-01') & 
                 (nc['appointment_date'] <= '2021-11-30')]
autumn_data
# Out:
#        appointment_date icb_ons_code  \
# 636          2021-09-01    E54000050
# 637          2021-09-01    E54000050
# 638          2021-09-01    E54000050
# 639          2021-09-01    E54000050
# 640          2021-09-01    E54000050
# ...                 ...          ...
# 810945       2021-11-30    E54000054
# 810946       2021-11-30    E54000054
# 810947       2021-11-30    E54000054
# 810948       2021-11-30    E54000054
# 810949       2021-11-30    E54000054
#
#                              sub_icb_location_name            service_setting  \
# 636     NHS North East and North Cumbria ICB - 00L                   Unmapped
# 637     NHS North East and North Cumbria ICB - 00L       Primary Care Network
# 638     NHS North East and North Cumbria ICB - 00L       Primary Care Network
# 639     NHS North East and North Cumbria ICB - 00L       Primary Care Network
# 640     NHS North East and North Cumbria ICB - 00L       Primary Care Network
# ...

# %%
# Look at September to November 2021 in more detail to allow a closer look.
# Create a separate data set that can be used in future weeks. 

autumn_data = nc[(nc['appointment_date'] >= '2021-09-01') & 
                 (nc['appointment_date'] <= '2021-11-30')]



# Aggregate the sum of 'count_of_appointments' by 'appointment_month' 
numbers_of_appointments_autumn_2021 = autumn_data.pivot_table(
    values='count_of_appointments',
    index='appointment_month',
    aggfunc='sum').reset_index()

# View the result
numbers_of_appointments_autumn_2021.head(5)

# Look at September to November 2021 in more detail to allow a closer look.

# Create lineplot
plt.figure(figsize=(8, 5))

sns.lineplot(
    x='appointment_month', 
    y='count_of_appointments', 
    data= numbers_of_appointments_autumn_2021)

# Formatting
plt.title("Appointments in Autumn 2021")
plt.xticks(rotation=45)
plt.xlabel("Month")
plt.ylabel("Total appointments in 10s of millions")
plt.grid(True)  

# Show plot
plt.show()

# %% [markdown]
# **Winter (December to February 2022):**

# %%
# Look at December to February 2022 in more detail to allow a closer look.
# Filter the dataset for 
winter_data = nc[(nc['appointment_date'] >= '2021-12-01') & 
                 (nc['appointment_date'] <= '2022-02-28')]
winter_data
# Out:
#        appointment_date icb_ons_code  \
# 2634         2021-12-01    E54000050
# 2635         2021-12-01    E54000050
# 2636         2021-12-01    E54000050
# 2637         2021-12-01    E54000050
# 2638         2021-12-01    E54000050
# ...                 ...          ...
# 813632       2022-02-28    E54000054
# 813633       2022-02-28    E54000054
# 813634       2022-02-28    E54000054
# 813635       2022-02-28    E54000054
# 813636       2022-02-28    E54000054
#
#                              sub_icb_location_name            service_setting  \
# 2634    NHS North East and North Cumbria ICB - 00L                   Unmapped
# 2635    NHS North East and North Cumbria ICB - 00L       Primary Care Network
# 2636    NHS North East and North Cumbria ICB - 00L       Primary Care Network
# 2637    NHS North East and North Cumbria ICB - 00L       Primary Care Network
# 2638    NHS North East and North Cumbria ICB - 00L       Primary Care Network
# ...

# %%
# Look at December to February 2022 in more detail to allow a closer look.
# Create a lineplot.

# Filter the dataset for 
winter_data = nc[(nc['appointment_date'] >= '2021-12-01') & 
                 (nc['appointment_date'] <= '2022-02-28')]


# Aggregate the sum of 'count_of_appointments' by 'appointment_month' 
numbers_of_appointments_winter_2021_2022 = winter_data.pivot_table(
    values='count_of_appointments',
    index='appointment_month',
    aggfunc='sum').reset_index()

# View the result
numbers_of_appointments_winter_2021_2022.head(5)

# Create a lineplot.
plt.figure(figsize=(8, 5))
sns.lineplot(
    x='appointment_month', 
    y='count_of_appointments', 
    data=numbers_of_appointments_winter_2021_2022,   
    marker='o' ) 

# Formatting
plt.title("Appointments in  Winter (Dec 2021 -Feb 2022)")
plt.xlabel("Month")
plt.ylabel("Total appointments in 10s of millions")
plt.grid(True) 
plt.xticks(
    ticks=numbers_of_appointments_winter_2021_2022['appointment_month'], 
    rotation=45)


# Show plot
plt.show()

# %% [markdown]
# **Spring (March to May 2022):**

# %%
# Look at March to May 2022 in more detail to allow a closer look.
# Filter the dataset for sprint months 
spring_data = nc[(nc['appointment_date'] >= '2022-03-01') & 
                 (nc['appointment_date'] <= '2022-05-31')]

spring_data
# Out:
#        appointment_date icb_ons_code  \
# 4454         2022-03-01    E54000050
# 4455         2022-03-01    E54000050
# 4456         2022-03-01    E54000050
# 4457         2022-03-01    E54000050
# 4458         2022-03-01    E54000050
# ...                 ...          ...
# 816466       2022-05-31    E54000054
# 816467       2022-05-31    E54000054
# 816468       2022-05-31    E54000054
# 816469       2022-05-31    E54000054
# 816470       2022-05-31    E54000054
#
#                              sub_icb_location_name            service_setting  \
# 4454    NHS North East and North Cumbria ICB - 00L                   Unmapped
# 4455    NHS North East and North Cumbria ICB - 00L       Primary Care Network
# 4456    NHS North East and North Cumbria ICB - 00L       Primary Care Network
# 4457    NHS North East and North Cumbria ICB - 00L       Primary Care Network
# 4458    NHS North East and North Cumbria ICB - 00L       Primary Care Network
# ...

# %%
# Look at March to May 2022 in more detail to allow a closer look.
# Filter the dataset for sprint months 
spring_data = nc[(nc['appointment_date'] >= '2022-03-01') & 
                 (nc['appointment_date'] <= '2022-05-31')]

spring_data 

# Aggregate appointment counts
numbers_of_appointments_spring = spring_data.pivot_table(
    values='count_of_appointments',
    index='appointment_month',
    aggfunc='sum').reset_index()


# View output
numbers_of_appointments_spring.head(5)

# Create a lineplot.
plt.figure(figsize=(8, 5))
sns.lineplot(
    x='appointment_month', 
    y='count_of_appointments', 
    data=numbers_of_appointments_spring) 

# Formatting
plt.title("Appointments in Spring 2022")
plt.xlabel("Month")
plt.ylabel("Total appointments in 10s of millions")
plt.grid(True) 
plt.xticks(
    ticks=numbers_of_appointments_spring['appointment_month'], 
    rotation=45)

# Show plot
plt.show()

# %%
# To see which region 's appointment status
attendance_data2 = location_ar[(location_ar['appointment_status'] != 'Unknown') & 
                               (location_ar['appointment_mode'] == 'Telephone')]
attendance_data2
# Out:
#        icb_ons_code appointment_month appointment_status  \
# 14        E54000034        2020-01-01           Attended
# 15        E54000034        2020-01-01           Attended
# 16        E54000034        2020-01-01           Attended
# 17        E54000034        2020-01-01           Attended
# 18        E54000034        2020-01-01           Attended
# ...             ...               ...                ...
# 596745    E54000050        2022-06-01                DNA
# 596750    E54000050        2022-06-01                DNA
# 596751    E54000050        2022-06-01                DNA
# 596752    E54000050        2022-06-01                DNA
# 596753    E54000050        2022-06-01                DNA
#
#                     hcp_type appointment_mode  \
# 14                        GP        Telephone
# 15                        GP        Telephone
# 16                        GP        Telephone
# 17                        GP        Telephone
# ...

# %%
# To see which region 's appointment status

attendance_data2 = location_ar[(location_ar['appointment_status'] != 'Unknown') & 
                               (location_ar['appointment_mode'] == 'Telephone')]

# Create pivot table
attendance_data2 = attendance_data2.pivot_table(
    values='count_of_appointments', 
    index=['REGION_NAME', 'appointment_mode'],  
    columns='appointment_status', 
    aggfunc='sum')

attendance_data2['Total Appointments'] = attendance_data2['Attended'] + attendance_data2['DNA']
attendance_data_sorted = attendance_data2[['Attended', 'DNA']].sort_values(by=['Attended', 'DNA'], ascending=False)

# Plotting the heatmap
plt.figure(figsize=(14, 8))
sns.heatmap(attendance_data_sorted, annot=True, fmt='g', cmap='coolwarm', cbar=True, linewidths=0.5)

# Customize the plot
plt.title('Attendance and Non-Attendance Appointments by Region')
plt.xlabel('Appointment Status')
plt.ylabel('Region')
plt.xticks(rotation=0) 
plt.tick_params(axis='both', which='both', labelsize=10)
plt.tight_layout()
plt.show()

# %%
# Create a  table to see which appoint mode is the mostly been attended
ar_status_clean =ar[ar['appointment_status'] != "Unknown"]
status_counts = ar_status_clean.groupby(['appointment_mode', 'appointment_status']).size().reset_index(name='count')
total_counts = ar_status_clean.groupby('appointment_mode')['appointment_status'].count().reset_index(name='total_count')
status_counts = status_counts.merge(total_counts[['appointment_mode', 'total_count']], on='appointment_mode')
status_counts['percentage'] = (status_counts['count'] / status_counts['total_count']) * 100
status_counts['percentage'] = status_counts['percentage'].round(2)

# Display the result
status_counts.head(20)
# Out:
#   appointment_mode appointment_status  count  total_count  percentage
# 0     Face-to-Face           Attended  64478       118248       54.53
# 1     Face-to-Face                DNA  53770       118248       45.47
# 2       Home Visit           Attended  48608        69994       69.45
# 3       Home Visit                DNA  21386        69994       30.55
# 4        Telephone           Attended  60796       110492       55.02
# 5        Telephone                DNA  49696       110492       44.98
# 6          Unknown           Attended  29526        53310       55.39
# 7          Unknown                DNA  23784        53310       44.61
# 8     Video/Online           Attended  28729        43453       66.12
# 9     Video/Online                DNA  14724        43453       33.88

# %%
# Create a  table to see which appoint mode is the mostly been attended
ar_status_clean =ar[ar['appointment_status'] != "Unknown"]
status_counts = ar_status_clean.groupby(['appointment_mode', 'appointment_status']).size().reset_index(name='count')
total_counts = ar_status_clean.groupby('appointment_mode')['appointment_status'].count().reset_index(name='total_count')
status_counts = status_counts.merge(total_counts[['appointment_mode', 'total_count']], on='appointment_mode')
status_counts['percentage'] = (status_counts['count'] / status_counts['total_count']) * 100
status_counts['percentage'] = status_counts['percentage'].round(2)

# Display the result
status_counts.head(20)

# Create a barplot to view the & of appointment status per appointment mode
plt.figure(figsize=(8, 5))
custom_palette = {
    "Attended": "green",
    "DNA": "red"}
sns.barplot(
    x='appointment_mode', 
    y='percentage', 
    data=status_counts,   
    hue ='appointment_status',
    palette=custom_palette) 

# Formatting
plt.title("The percentage of the appointment status per appointment mode")
plt.xlabel("Appointment modes")
plt.ylabel("The appointments status in % ")
plt.grid(True) 
plt.legend(title="Appointment status", bbox_to_anchor=(1,1)) 
plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)

# Show plot
plt.show()

# %%
# Create a dataframe for the sub_icb_location_code with Region Name for appointment duration

location_ad = pd.merge ( ad, location, how ='left', on = 'icb_ons_code')
location_ad
location_ad.isnull().sum()
# Out:
# sub_icb_location_code        0
# sub_icb_location_ons_code    0
# sub_icb_location_name        0
# icb_ons_code                 0
# region_ons_code              0
# appointment_date             0
# actual_duration              0
# count_of_appointments        0
# year                         0
# month                        0
# appointment_year_month       0
# REGION_NAME                  0
# dtype: int64

# %%
# Create a dataframe for the sub_icb_location_code with Region Name for national categories
location = pd.read_csv('location.csv')
location.head()

location_nc = pd.merge ( nc, location, how ='left', on = 'icb_ons_code')
location_nc
location_nc.isnull().sum()
# Out:
# appointment_date         0
# icb_ons_code             0
# sub_icb_location_name    0
# service_setting          0
# context_type             0
# national_category        0
# count_of_appointments    0
# appointment_month        0
# appointment_year         0
# REGION_NAME              0
# dtype: int64

# %%
# Create a dataframe for the sub_icb_location_code with Region Name for apppointment regional

location = pd.read_csv('location.csv')
location.head()

location_ar = pd.merge ( ar, location, how ='left', on = 'icb_ons_code')
location_ar

location_ar.isnull().sum()
# Out:
# icb_ons_code                         0
# appointment_month                    0
# appointment_status                   0
# hcp_type                             0
# appointment_mode                     0
# time_between_book_and_appointment    0
# count_of_appointments                0
# year                                 0
# month                                0
# REGION_NAME                          0
# dtype: int64

# %%
 #Create a pivot table to see which region has the most appointment
appointment_mode_region =location_ar.pivot_table(
    values = 'count_of_appointments',
    index = [ 'REGION_NAME'],
    aggfunc ='sum').reset_index().sort_values(by='count_of_appointments', ascending=False)

# View output.
appointment_mode_region.head(5)
# Create a lineplot.
plt.figure(figsize=(8, 5))
sns.barplot(
    x='REGION_NAME', 
    y='count_of_appointments', 
    data=appointment_mode_region,   
    hue ='REGION_NAME' ) 

# Formatting
plt.title("Which region has the most appointment?")
plt.xlabel("Regions")
plt.ylabel("Count of appointments(in million)")
plt.grid(True) 
plt.xticks(rotation=45)
plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)


# Show plot
plt.show()

# %%
# Create a DataFrame  to see month has the most appointments
numbers_of_appointments = (location_ar .groupby(['appointment_month', 'REGION_NAME'])['count_of_appointments'].sum().reset_index())
numbers_of_appointments

# Create a lineplot.
plt.figure(figsize=(20, 10))  
sns.lineplot(
    x='appointment_month', 
    y='count_of_appointments', 
    data=numbers_of_appointments,  
    hue='REGION_NAME'  
)

# Formatting
plt.title("Appointments Over Time by Region", fontsize=14)
plt.xlabel("Appointment Month", fontsize=12)  
plt.ylabel("Count of Appointments (in million)", fontsize=12)
plt.grid(True) 
plt.xticks(rotation=45)  
plt.legend(title="Regions", bbox_to_anchor=(0,1)) 
plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)

# Show plot
plt.show()

# %%
# Find the outliners of the appointments per region



location_ar['appointment_month'] = pd.to_datetime(location_ar['appointment_month'])

ar_quarter = location_ar[(location_ar['appointment_status'] == 'Attended')] 

Q1_2020 = ar_quarter[(ar_quarter['appointment_month'].dt.year == 2020) & (ar_quarter['appointment_month'].dt.quarter == 1)].copy()
Q2_2020 = ar_quarter[(ar_quarter['appointment_month'].dt.year == 2020) & (ar_quarter['appointment_month'].dt.quarter == 2)].copy()
Q3_2020 = ar_quarter[(ar_quarter['appointment_month'].dt.year == 2020) & (ar_quarter['appointment_month'].dt.quarter == 3)].copy()
Q4_2020 = ar_quarter[(ar_quarter['appointment_month'].dt.year == 2020) & (ar_quarter['appointment_month'].dt.quarter == 4)].copy()

Q1_2021 = ar_quarter[(ar_quarter['appointment_month'].dt.year == 2021) & (ar_quarter['appointment_month'].dt.quarter == 1)].copy()
Q2_2021 = ar_quarter[(ar_quarter['appointment_month'].dt.year == 2021) & (ar_quarter['appointment_month'].dt.quarter == 2)].copy()
Q3_2021 = ar_quarter[(ar_quarter['appointment_month'].dt.year == 2021) & (ar_quarter['appointment_month'].dt.quarter == 3)].copy()
Q4_2021 = ar_quarter[(ar_quarter['appointment_month'].dt.year == 2021) & (ar_quarter['appointment_month'].dt.quarter == 4)].copy()

# Assign quarter labels
Q1_2020.loc[:, "Quarter"] = "Q1 2020"
Q2_2020.loc[:, "Quarter"] = "Q2 2020"
Q3_2020.loc[:, "Quarter"] = "Q3 2020"
Q4_2020.loc[:, "Quarter"] = "Q4 2020"
Q1_2021.loc[:, "Quarter"] = "Q1 2021"
Q2_2021.loc[:, "Quarter"] = "Q2 2021"
Q3_2021.loc[:, "Quarter"] = "Q3 2021"
Q4_2021.loc[:, "Quarter"] = "Q4 2021"

# Combine all quarters
combined_df = pd.concat([Q1_2020, Q2_2020, Q3_2020, Q4_2020, Q1_2021, Q2_2021, Q3_2021, Q4_2021])

# Create a box plot to see the outlier and distribution by Quaterly 
plt.figure(figsize=(10, 6))
sns.boxplot(x='Quarter', y='count_of_appointments', data=combined_df)
plt.suptitle("Distribution of Attended Appointments per Quarter in 2020-2021", fontsize=16)
plt.title("Q1 (Jan to Mar) has more appointments", fontsize=14)
plt.xlabel("Quarter and Year", fontsize=12)  
plt.ylabel("Total appointments", fontsize=12)
plt.show()

# %%
# Found out the attendance rate 
ar_mode_clean =  ar[ar['appointment_status'] != "Unknown"]
ar_mode_clean

appointment_mode_counts = ar.groupby('appointment_status')['count_of_appointments'].sum()
appointment_mode_counts
# Out:
# appointment_status
# Attended    677755876
# DNA          30911233
# Unknown      34137416
# Name: count_of_appointments, dtype: int64

# %%
# Found out the attendance rate 
ar_mode_clean =  ar[ar['appointment_status'] != "Unknown"]
ar_mode_clean

appointment_mode_counts = ar.groupby('appointment_status')['count_of_appointments'].sum()

#Create a pieplot to show the appointment mode vs appointments
plt.figure(figsize=(10,6))
# Defining colors for the pie chart 
colors = { "Attended": "green","DNA": "red"}
  
plt.figure(figsize=(20, 10))  

# Plotting the pie chart
appointment_mode_counts.plot(kind='pie', autopct='%1.0f%%', colors=[colors.get(status, 'gray') for status in appointment_mode_counts.index],
                             textprops={'fontsize': 14}, figsize=(10, 6))

# Formatting the plot
plt.title("Percentage of Appointment status- Over 90% appointments were attended", fontsize=16)
plt.ylabel("")
plt.legend(title='Appointment Modes', bbox_to_anchor=(1, 0.2))
plt.subplots_adjust(left=0.5, right=1.5, top=1.2, bottom=0.1)

plt.show()

# %% [markdown]
# # Assignment activity 5

# %% [markdown]
# ### Analyse tweets from Twitter with hashtags related to healthcare in the UK.

# %%
# Libraries and settings needed for analysis
import pandas as pd
import seaborn as sns

# Set figure size.
sns.set(rc={'figure.figsize':(15, 12)})

# Set the plot style as white.
sns.set_style('white')

# Maximum column width to display
pd.options.display.max_colwidth = 200

# %%
# Load the data set.
X = pd.read_csv('tweets.csv')

# View the DataFrame.
X
# Out:
#           tweet_id  \
# 0     1.567630e+18
# 1     1.567580e+18
# 2     1.567580e+18
# 3     1.567580e+18
# 4     1.567580e+18
# ...            ...
# 1169  1.567580e+18
# 1170  1.567580e+18
# 1171  1.567580e+18
# 1172  1.567580e+18
# 1173  1.567580e+18
#
#                                                                                                                                                                                               tweet_full_text  \
# 0     As Arkansas’ first Comprehensive Stroke Certified Center, UAMS provides Arkansans with access to the most advanced stoke care. Join us in our mission to make a difference in the health and well-be...
# 1                                                                 RT @AndreaGrammer: Work-life balance is at the foundation of how decisions are made and where #PremiseHealth is headed.  We're #hiring for…
# ...

# %%
# Explore the metadata.
X.describe
X.info
# Out:
# <bound method DataFrame.info of           tweet_id  \
# 0     1.567630e+18
# 1     1.567580e+18
# 2     1.567580e+18
# 3     1.567580e+18
# 4     1.567580e+18
# ...            ...
# 1169  1.567580e+18
# 1170  1.567580e+18
# 1171  1.567580e+18
# 1172  1.567580e+18
# 1173  1.567580e+18
#
#                                                                                                                                                                                               tweet_full_text  \
# 0     As Arkansas’ first Comprehensive Stroke Certified Center, UAMS provides Arkansans with access to the most advanced stoke care. Join us in our mission to make a difference in the health and well-be...
# 1                                                                 RT @AndreaGrammer: Work-life balance is at the foundation of how decisions are made and where #PremiseHealth is headed.  We're #hiring for…
# ...

# %%
# Explore the data set.
X.shape
X.isnull().sum()

# Remove the null values 
x_cleanned = X.dropna()
x_cleanned
x_cleanned.isna().sum()
# Out:
# tweet_id                   0
# tweet_full_text            0
# tweet_entities             0
# tweet_entities_hashtags    0
# tweet_metadata             0
# tweet_retweet_count        0
# tweet_favorite_count       0
# tweet_favorited            0
# tweet_retweeted            0
# tweet_lang                 0
# dtype: int64

# %%
# Would it be useful to only look at retweeted and favourite tweet messages?
x_cleanned[['tweet_retweet_count', 'tweet_favorite_count']].value_counts()
# Out:
# tweet_retweet_count  tweet_favorite_count
# 0                    0                       435
# 1                    0                       138
# 0                    1                        70
# 2                    0                        69
# 3                    0                        46
#                                             ...
# 5                    10                        1
# 7                    1                         1
# 8                    11                        1
# 9                    5                         1
# 169                  0                         1
# Name: count, Length: 67, dtype: int64

# %%
# Would it be useful to only look at retweeted and favourite tweet messages?
# Explain your answer.
# No, because those data does not explain well enough why they've been retweeted and favourited and retweeted does not mean favorited

# %%
# Create a new DataFrame containing only the text.
tweet_full_text = x_cleanned['tweet_full_text']

# View the DataFrame.
tweet_full_text
# Out:
# 0       As Arkansas’ first Comprehensive Stroke Certified Center, UAMS provides Arkansans with access to the most advanced stoke care. Join us in our mission to make a difference in the health and well-be...
# 1                                                                   RT @AndreaGrammer: Work-life balance is at the foundation of how decisions are made and where #PremiseHealth is headed.  We're #hiring for…
# 2                                                                RT @OntarioGreens: $10 billion can go a long way to fixing our broken #Healthcare system.\n\nYet Doug Ford would rather spend it ALL on a hig…
# 3                                                                  RT @modrnhealthcr: 🚨#NEW:🚨 Insurance companies are figuring out the best ways to collect information about members’ race and ethnicity data…
# ...

# %%
#Create a new DataFrame with only text values
tweets_text = x_cleanned[['tweet_full_text']].copy()

# %%
# Loop through the messages, and create a list of values containing the # symbol.
tags = []
for y in [x.split(' ') for x in tweets_text['tweet_full_text'].values]:
    for z in y:
        if '#' in z:
            # Change to lowercase.
            tags.append(z.lower())

# %%
# Display the first 30 records.
tags_series = pd.Series(tags).value_counts()
print(tags_series.head(30))
# Out:
# #healthcare                    716
# #health                         80
# #medicine                       41
# #ai                             40
# #job                            38
# #medical                        35
# #strategy                       30
# #pharmaceutical                 28
# #pharma                         25
# #marketing                      25
# #digitalhealth                  25
# #biotech                        24
# #medtwitter                     24
# #competitiveintelligence        24
# #meded                          23
# #vaccine                        18
# #hiring                         18
# #news                           17
# #machinelearning                17
# #technology                     17
# #competitivemarketing           16
# #coronavirus                    16
# #womeninmedicine                16
# #covid                          16
# #wellness                       15
# #healthtech                     15
# #doctorofveterinarymedicine     14
# ...

# %%
# Convert the series to a DataFrame in preparation for visualisation.
tags_series.astype(str)
# Rename the columns.
tags_df = tags_series.reset_index()
tags_df.columns = ['#text', 'count_of_hashtag_text']
#View the DataFrame
tags_df.head()
# Out:
#          #text  count_of_hashtag_text
# 0  #healthcare                    716
# 1      #health                     80
# 2    #medicine                     41
# 3          #ai                     40
# 4         #job                     38

# %%
# Fix the count datatype.
tags_df['count_of_hashtag_text'] = tags_df['count_of_hashtag_text'].astype(int)
# View the result.
tags_df.head()

# Display records where the count is larger than 50.
filtered_tags_df = tags_df[tags_df['count_of_hashtag_text'] > 20].sort_values(by='count_of_hashtag_text', ascending=False)
filtered_tags_df
# Out:
#                        #text  count_of_hashtag_text
# 0                #healthcare                    716
# 1                    #health                     80
# 2                  #medicine                     41
# 3                        #ai                     40
# 4                       #job                     38
# 5                   #medical                     35
# 6                  #strategy                     30
# 7            #pharmaceutical                     28
# 8                    #pharma                     25
# 9                 #marketing                     25
# 10            #digitalhealth                     25
# 11                  #biotech                     24
# 12               #medtwitter                     24
# 13  #competitiveintelligence                     24
# 14                    #meded                     23

# %%
group_mapping = {
    '#health': 'Health',
    '#healthcare': 'Health',
    '#healthcare': 'Health',
    '#medicalcare': 'Health',
    '#covid': 'Covid',
    '#covid19': 'Covid',
    '#mental health': 'Health',
    '#medicine' : 'Health',
    '#medicine': 'Health',
    '#ai' : 'Tech',
    '#job' : 'Job',
    '#medical' : 'Health',
    '#strategy' : 'Strategy',
    '#pharmaceutical' : 'Health',
    '#pharma': 'Health',
    '#digitalhealth' : 'Tech',
    '#marketing' :'Job',
    '#biotech': 'Health',
    '#medtwitter': 'Health',
    '#competitiveintelligence' :'Job',
    '#meded' :'Health'}
filtered_tags_df['group'] = filtered_tags_df['#text'].map(group_mapping)
filtered_tags_df
# Out:
#                        #text  count_of_hashtag_text     group
# 0                #healthcare                    716    Health
# 1                    #health                     80    Health
# 2                  #medicine                     41    Health
# 3                        #ai                     40      Tech
# 4                       #job                     38       Job
# 5                   #medical                     35    Health
# 6                  #strategy                     30  Strategy
# 7            #pharmaceutical                     28    Health
# 8                    #pharma                     25    Health
# 9                 #marketing                     25       Job
# 10            #digitalhealth                     25      Tech
# 11                  #biotech                     24    Health
# 12               #medtwitter                     24    Health
# 13  #competitiveintelligence                     24       Job
# ...

# %%
# Create a barplot dive deep in the categories
grouped_sum = filtered_tags_df.groupby('group')['count_of_hashtag_text'].sum().reset_index()
grouped_sum 

# Create a Seaborn barplot indicating records with a count >20 records.
# Set figure size
plt.figure(figsize=(12, 6))

# Create lineplot
sns.barplot(
    x ='group', 
    y='count_of_hashtag_text', 
    data=grouped_sum , 
    hue='group')

# Formatting
plt.title("People mostly concerned in health care", fontsize = 14)
plt.suptitle("Categorise been mentioned more than 20 times on twitter" , fontsize =16)
plt.xlabel("Categorise")
plt.ylabel("Number of hashtags been shown on twitter") 
plt.grid(True)  
plt.savefig("Hashtag shown more than 20 times on text.png")

# Show plot
plt.show()

# %% [markdown]
# #

# %% [markdown]
# # Assignment activity 6

# %% [markdown]
# ### Make recommendations to the NHS.

# %%
# Prepare your workstation.
# Load the appointments_regional.csv file.


# View the DataFrame.

# %%
# Print the min and max dates.
ar ['appointment_month'].agg(['min', 'max'])
# Out:
# min    01/01/2020
# max    12/01/2021
# Name: appointment_month, dtype: object

# %%
# Filter the data set to only look at data from 2021-08 onwards.
ar_filter= ar[(ar['appointment_month'] >= '2021-08-01') & 
                 (ar['appointment_month'] <= '2022-06-01')]
ar_filter
# Out:
# Empty DataFrame
# Columns: [icb_ons_code, appointment_month, appointment_status, hcp_type, appointment_mode, time_between_book_and_appointment, count_of_appointments, year, month]
# Index: []

# %% [markdown]
# **Question 1:** Should the NHS start looking at increasing staff levels?

# %%
# Create an aggregated data set to review the different features.
ar_agg = ar[['appointment_month','hcp_type','appointment_status','appointment_mode','time_between_book_and_appointment','count_of_appointments']]
# View the DataFrame.
ar_agg
# Out:
#        appointment_month hcp_type appointment_status appointment_mode  \
# 0             01/01/2020       GP           Attended     Face-to-Face
# 1             01/01/2020       GP           Attended     Face-to-Face
# 2             01/01/2020       GP           Attended     Face-to-Face
# 3             01/01/2020       GP           Attended     Face-to-Face
# 4             01/01/2020       GP           Attended     Face-to-Face
# ...                  ...      ...                ...              ...
# 596816        06/01/2022  Unknown            Unknown          Unknown
# 596817        06/01/2022  Unknown            Unknown          Unknown
# 596818        06/01/2022  Unknown            Unknown          Unknown
# 596819        06/01/2022  Unknown            Unknown          Unknown
# 596820        06/01/2022  Unknown            Unknown          Unknown
#
#        time_between_book_and_appointment  count_of_appointments
# ...

# %%
# Determine the total number of appointments per month for whole year

ar_df =ar.groupby(['appointment_month'])['count_of_appointments'].sum().reset_index()
# Add a new column to indicate the average utilisation of services.
# Monthly aggregate / 30 to get to a daily value.
ar_df['utilisation'] = ar_df  ['count_of_appointments'] / 30

max_capacity = 1200000
max_capacity_rounded = round(max_capacity, 1)
ar_df ['utilisation_vs_capacity%'] = ar_df ['utilisation'] / max_capacity_rounded * 100

# View the DataFrame.
ar_df
# Out:
#    appointment_month  count_of_appointments   utilisation  \
# 0         01/01/2020               27199296  9.066432e+05
# 1         01/01/2021               22492069  7.497356e+05
# 2         01/01/2022               25635474  8.545158e+05
# 3         02/01/2020               24104621  8.034874e+05
# 4         02/01/2021               22399569  7.466523e+05
# 5         02/01/2022               25355260  8.451753e+05
# 6         03/01/2020               24053468  8.017823e+05
# 7         03/01/2021               27225424  9.075141e+05
# 8         03/01/2022               29595038  9.865013e+05
# 9         04/01/2020               16007881  5.335960e+05
# 10        04/01/2021               23879932  7.959977e+05
# 11        04/01/2022               23913060  7.971020e+05
# 12        05/01/2020               16417212  5.472404e+05
# 13        05/01/2021               23508395  7.836132e+05
# 14        05/01/2022               27495508  9.165169e+05
# ...

# %%
# Plot monthly appointments for whole year

# Create a lineplot.

plt.figure(figsize=(20, 10))  
sns.lineplot(
    x='appointment_month', 
    y='count_of_appointments', 
    data=ar_df)

# Formatting
plt.title("Appointments per month from 2020-01 to 2022-06", fontsize=14)
plt.xlabel("Appointment Month", fontsize=12)  
plt.ylabel("Total appointments", fontsize=12)
plt.grid(True) 
plt.xticks(rotation=45)  
plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)
plt.savefig("Appointments per month from 2020-01 to 2022-06.png")

# Show plot
plt.show()

# %%
# Plot monthly appointments for whole year

# Create a barplot.

plt.figure(figsize=(20, 10))  
sns.barplot(
    x='REGION_NAME', 
    y='count_of_appointments', 
    data=location_ar,
    hue= 'REGION_NAME')

# Formatting
plt.title("Appointments per region from 2020-01 to 2022-06", fontsize=14)
plt.xlabel("Regions", fontsize=12)  
plt.ylabel("Total appointments", fontsize=12)
plt.grid(True) 
plt.xticks(rotation=45)  
plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)
plt.savefig("Appointments per region from 2020-01 to 2022-06")

# Show plot
plt.show()

# %%
# Plot sum of count of monthly visits post covid
# Convert the appointment_month to string data type for ease of visualisation.
ar_df ['appointment_month'] = ar_df ['appointment_month'].astype(str)


# Create a lineplot with Seaborn.
plt.figure(figsize=(20, 10))  
sns.lineplot(
    x='appointment_month', 
    y='count_of_appointments', 
    data=ar_df )

# Formatting
plt.title("Appointments per month", fontsize=14)
plt.xlabel("Appointment Month", fontsize=12)  
plt.ylabel("Count of Appointments (in million)", fontsize=12)
plt.grid(True) 
plt.xticks(rotation=45)  

# Show plot
plt.show()

# %%
ar_df =ar.groupby(['appointment_month'])['count_of_appointments'].sum().reset_index()
# Add a new column to indicate the average utilisation of services.
# Monthly aggregate / 30 to get to a daily value.
ar_df['utilisation'] = ar_df  ['count_of_appointments'] / 30

max_capacity = 1200000
max_capacity_rounded = round(max_capacity, 1)
ar_df ['utilisation_vs_capacity%'] = ar_df ['utilisation'] / max_capacity_rounded * 100

# View the DataFrame.
ar_df
# Out:
#    appointment_month  count_of_appointments   utilisation  \
# 0         01/01/2020               27199296  9.066432e+05
# 1         01/01/2021               22492069  7.497356e+05
# 2         01/01/2022               25635474  8.545158e+05
# 3         02/01/2020               24104621  8.034874e+05
# 4         02/01/2021               22399569  7.466523e+05
# 5         02/01/2022               25355260  8.451753e+05
# 6         03/01/2020               24053468  8.017823e+05
# 7         03/01/2021               27225424  9.075141e+05
# 8         03/01/2022               29595038  9.865013e+05
# 9         04/01/2020               16007881  5.335960e+05
# 10        04/01/2021               23879932  7.959977e+05
# 11        04/01/2022               23913060  7.971020e+05
# 12        05/01/2020               16417212  5.472404e+05
# 13        05/01/2021               23508395  7.836132e+05
# 14        05/01/2022               27495508  9.165169e+05
# ...

# %%
# Determine the total number of appointments per month for whole year

ar_df =ar.groupby(['appointment_month'])['count_of_appointments'].sum().reset_index()
# Add a new column to indicate the average utilisation of services.
# Monthly aggregate / 30 to get to a daily value.
ar_df['utilisation'] = ar_df  ['count_of_appointments'] / 30

max_capacity = 1200000
max_capacity_rounded = round(max_capacity, 1)
ar_df ['utilisation_vs_capacity%'] = ar_df ['utilisation'] / max_capacity_rounded * 100

# View the DataFrame.
ar_df

# Plot monthly capacity utilisation.
ar_df ['appointment_month'] = ar_df ['appointment_month'].astype(str)

# Create a lineplot.

plt.figure(figsize=(20, 10))  
ax = sns.pointplot(
    x='appointment_month', 
    y='utilisation_vs_capacity%', 
    data=ar_df)
sns.regplot(data=ar_df, x=ar_df.index, y='utilisation_vs_capacity%', scatter=False, color='red', label="Trend Line")

# Formatting
plt.title("NHS GP service is reaching over 70% utilisation during Jan 20 to Jun 22", fontsize=14)
plt.suptitle("% Capacity Utilisation in all regions from  01-2020 to 06-2022", fontsize=16)
plt.xlabel(" Month", fontsize=12)  
plt.ylabel("Utilisation vs Capacity (%)", fontsize=12)
plt.grid(True) 
plt.xticks(rotation=45)  
plt.gca().yaxis.get_major_formatter().set_useOffset(False)
plt.xlim((0,30))
ax.annotate( "The first national lockdown in Mar 2020 ", 
    xy=(3, 45),  
    xytext=(5, 45),
    color='red',  
    fontsize=12,  
    fontweight='bold',  
    arrowprops=dict(arrowstyle="->", color='blue', linewidth=2))
plt.savefig("Utilisation per month.png")


# Show plot
plt.show()

# %% [markdown]
# **Question 2:** How do the healthcare professional types differ over time?

# %%
# Determine the total number of appointments per month per hcp.

ar_df_hcp = ar.groupby(['appointment_month', 'hcp_type'])['count_of_appointments'].sum().reset_index()

# View the DataFrame.
ar_df_hcp
# Out:
#    appointment_month              hcp_type  count_of_appointments
# 0         01/01/2020                    GP               14168932
# 1         01/01/2020  Other Practice staff               12326031
# 2         01/01/2020               Unknown                 704333
# 3         01/01/2021                    GP               11806927
# 4         01/01/2021  Other Practice staff               10001104
# ..               ...                   ...                    ...
# 85        12/01/2020  Other Practice staff               11021668
# 86        12/01/2020               Unknown                 754454
# 87        12/01/2021                    GP               12654767
# 88        12/01/2021  Other Practice staff               11614470
# 89        12/01/2021               Unknown                 871539
#
# [90 rows x 3 columns]

# %%
# Determine the total number of appointments per month per hcp.

ar_df_hcp = ar.groupby(['appointment_month', 'hcp_type'])['count_of_appointments'].sum().reset_index()

# View the DataFrame.
ar_df_hcp

# Create a line plot to answer the question.
plt.figure(figsize=(20, 10))  
sns.lineplot(
    x='appointment_month', 
    y='count_of_appointments', 
    data=ar_df_hcp,
    hue = 'hcp_type')

# Formatting
plt.title("Trends of Healthcare Professional Types Over Time", fontsize=14)
plt.xlabel("Appointment Month", fontsize=12)  
plt.ylabel("Number of Appointments", fontsize=12)
plt.grid(True) 
plt.xticks(rotation=45)  
plt.xlim((0,30))
plt.legend(title='Healthcare Professional Type')

# Show plot
plt.show()

# %% [markdown]
# **Question 3:** Are there significant changes in whether or not visits are attended?

# %%
# Create a line plot to answer the question.
ar_df_status = ar.groupby(['appointment_month', 'appointment_status'])['count_of_appointments'].sum().reset_index()
ar_df_status
# Out:
#    appointment_month appointment_status  count_of_appointments
# 0         01/01/2020           Attended               24538291
# 1         01/01/2020                DNA                1298269
# 2         01/01/2020            Unknown                1362736
# 3         01/01/2021           Attended               20645718
# 4         01/01/2021                DNA                 899833
# ..               ...                ...                    ...
# 85        12/01/2020                DNA                 996416
# 86        12/01/2020            Unknown                 947299
# 87        12/01/2021           Attended               22853483
# 88        12/01/2021                DNA                1198866
# 89        12/01/2021            Unknown                1088427
#
# [90 rows x 3 columns]

# %%
# Create a line plot to answer the question.

ar_df_status = ar.groupby(['appointment_month', 'appointment_status'])['count_of_appointments'].sum().reset_index()
ar_df_status

plt.figure(figsize=(20, 10))  
sns.lineplot(
    x='appointment_month', 
    y='count_of_appointments', 
    data=ar_df_status,
    hue = 'appointment_status')

# Formatting
plt.title("Trends of Appointment Status Over Time", fontsize=14)
plt.xlabel("Appointment Month", fontsize=12)  
plt.ylabel("Number of Appointments", fontsize=12)
plt.grid(True) 
plt.xticks(rotation=45)  
plt.legend(title='Appointment Status')
plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)

# Show plot
plt.show()

# %% [markdown]
# **Question 4:** Are there changes in terms of appointment type and the busiest months?

# %%
ar_clean = ar[ar['appointment_mode'] != 'Unknown']
ar_df_mode = ar_clean.groupby(['appointment_month', 'appointment_mode'])['count_of_appointments'].sum().reset_index()
ar_df_mode
# Create a line plot to answer the question.
plt.figure(figsize=(10, 6))  
ax = sns.lineplot(
    x='appointment_month', 
    y='count_of_appointments', 
    data=ar_df_mode,
    hue = 'appointment_mode')

# Formatting
plt.xlabel("Appointment Month", fontsize=12)  
plt.ylabel("Number of Appointments", fontsize=12)
plt.grid(True) 
plt.xticks(rotation=45)  
plt.legend(title='Appointment Modes', bbox_to_anchor=(1,1)) 
plt.title("How Covid-19 changed the perfered appointment mode", fontsize=10)
plt.suptitle("Trends of Appointment Mode Over Time", fontsize=16)
ax.annotate( "The first national lockdown in Mar 2020 ", 
    xy=(3, 8000000),  
    xytext=(5, 8000000),
    color='red',  
    fontsize=12,  
    fontweight='bold',  
    arrowprops=dict(arrowstyle="->", color='blue', linewidth=2))
plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)


# Show plot
plt.show()

# %%
# Ensure correct filtering before pivoting to see telephone appointment increased in details figure
ar_df_mode_filtered = ar_df_mode[ar_df_mode['appointment_mode'] == 'Telephone']

# Pivot table with the correct index and aggregation
ar_df_mode_pivot = ar_df_mode_filtered.pivot_table(
    values='count_of_appointments',
    index=['appointment_mode', 'appointment_month'],  # Fixed indexing
    aggfunc='sum'
).reset_index()

# Display the pivot table
ar_df_mode_pivot.head()
# Out:
#   appointment_mode appointment_month  count_of_appointments
# 0        Telephone        01/01/2020                3701775
# 1        Telephone        01/01/2021                9571141
# 2        Telephone        01/01/2022                9212553
# 3        Telephone        02/01/2020                3322242
# 4        Telephone        02/01/2021                9546051

# %% [markdown]
# **Question 5:** Are there any trends in time between booking and appointment?

# %%
# To view the trends in time between book and appointments
ar_df_time = ar.groupby(['appointment_month', 'time_between_book_and_appointment'])['count_of_appointments'].sum().reset_index()
ar_df_time_clean = ar[ar['time_between_book_and_appointment'] != "Unknown / Data Quality"]
ar_df_time_clean
# Out:
#        icb_ons_code appointment_month appointment_status hcp_type  \
# 0         E54000034        01/01/2020           Attended       GP
# 1         E54000034        01/01/2020           Attended       GP
# 2         E54000034        01/01/2020           Attended       GP
# 3         E54000034        01/01/2020           Attended       GP
# 4         E54000034        01/01/2020           Attended       GP
# ...             ...               ...                ...      ...
# 596816    E54000050        06/01/2022            Unknown  Unknown
# 596817    E54000050        06/01/2022            Unknown  Unknown
# 596818    E54000050        06/01/2022            Unknown  Unknown
# 596819    E54000050        06/01/2022            Unknown  Unknown
# 596820    E54000050        06/01/2022            Unknown  Unknown
#
#        appointment_mode time_between_book_and_appointment  \
# 0          Face-to-Face                             1 Day
# ...

# %%
# To view the trends in time between book and appointments

ar_df_time = ar.groupby(['appointment_month', 'time_between_book_and_appointment'])['count_of_appointments'].sum().reset_index()
ar_df_time_clean = ar[ar['time_between_book_and_appointment'] != "Unknown / Data Quality"]

# Create a line plot to answer the question.
plt.figure(figsize=(20, 10))  
sns.lineplot(
    x='appointment_month', 
    y='count_of_appointments', 
    data=ar_df_time_clean,
    hue = 'time_between_book_and_appointment')

# Formatting
plt.title("Trends of Time Between Book and Appointment Over Time", fontsize=14)
plt.xlabel("Appointment Month", fontsize=12)  
plt.ylabel("Number of Appointments", fontsize=12)
plt.grid(True) 
plt.xticks(rotation=45)  
plt.legend(title='Time between Book and Appointment', bbox_to_anchor=(1,1)) 
plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)

# Show plot
plt.show()

# %%
# Create a table to view the trend of time between book and appointment and attended appointments 

ar_df_time_clean = ar.groupby(['time_between_book_and_appointment','appointment_status'])['count_of_appointments'].sum().reset_index()
ar_df_time_clean= ar_df_time_clean[(ar_df_time_clean['time_between_book_and_appointment'] != "Unknown / Data Quality") & 
    (ar_df_time_clean['appointment_status'] != "Unknown")]
ar_df_time_clean_attended = ar_df_time_clean.sort_values('count_of_appointments', ascending = False)
ar_df_time_clean_attended=ar_df_time_clean[ar_df_time_clean2 ['appointment_status']== 'Attended']
group_mapping = {
    'Same Day': 'Same Day',
    '1 Day': '1 Day',
    '2 to 7 Days': '2 - 7 Days',
    '8  to 14 Days': '8 - 14 Days',
    '15  to 21 Days': '15 - 21 Days',
    '22  to 28 Days': '22 - 28 Days',
    'More than 28 Days': '28 Days +'}
ar_df_time_clean_attended['group'] = ar_df_time_clean_attended['time_between_book_and_appointment'].map(group_mapping)

# Define the correct order
category_order = ['Same Day', '1 Day', '2 - 7 Days', '8 - 14 Days', 
                  '15 - 21 Days', '22 - 28 Days', '28 Days +']
# Convert column to categorical with the correct order
ar_df_time_clean_attended['group'] = pd.Categorical(
    ar_df_time_clean_attended['group'], 
    categories=category_order, 
    ordered=True)
# Map categories to numeric values
category_map = {category: idx for idx, category in enumerate(category_order)}
ar_df_time_clean_attended['time_numeric'] = ar_df_time_clean_attended['group'].map(category_map)
# Sort DataFrame based on the categorical order
ar_df_time_clean_attended = ar_df_time_clean_attended.sort_values('group')
ar_df_time_clean_attended
# Out:
#    time_between_book_and_appointment appointment_status  \
# 18                          Same Day           Attended
# 0                              1 Day           Attended
# 6                        2 to 7 Days           Attended
# 12                     8  to 14 Days           Attended
# 3                     15  to 21 Days           Attended
# 9                     22  to 28 Days           Attended
# 15                 More than 28 Days           Attended
#
#     count_of_appointments         group time_numeric
# 18              328380317      Same Day            0
# 0                62556833         1 Day            1
# 6               138103022    2 - 7 Days            2
# 12               75092108   8 - 14 Days            3
# 3                35842753  15 - 21 Days            4
# 9                20798309  22 - 28 Days            5
# 15               16699531     28 Days +            6

# %%
# Create a table to view the trend of time between book and appointment and attended appointments 
ar_df_time_clean = ar.groupby(['time_between_book_and_appointment','appointment_status'])['count_of_appointments'].sum().reset_index()
ar_df_time_clean= ar_df_time_clean[(ar_df_time_clean['time_between_book_and_appointment'] != "Unknown / Data Quality") & 
    (ar_df_time_clean['appointment_status'] != "Unknown")]
ar_df_time_clean_attended = ar_df_time_clean.sort_values('count_of_appointments', ascending = False)
ar_df_time_clean_attended=ar_df_time_clean[ar_df_time_clean ['appointment_status']== 'Attended']
group_mapping = {
    'Same Day': 'Same Day',
    '1 Day': '1 Day',
    '2 to 7 Days': '2 - 7 Days',
    '8  to 14 Days': '8 - 14 Days',
    '15  to 21 Days': '15 - 21 Days',
    '22  to 28 Days': '22 - 28 Days',
    'More than 28 Days': '28 Days +'}
ar_df_time_clean_attended['group'] = ar_df_time_clean_attended['time_between_book_and_appointment'].map(group_mapping)

# Define the correct order
category_order = ['Same Day', '1 Day', '2 - 7 Days', '8 - 14 Days', 
                  '15 - 21 Days', '22 - 28 Days', '28 Days +']
# Convert column to categorical with the correct order
ar_df_time_clean_attended['group'] = pd.Categorical(
    ar_df_time_clean_attended['group'], 
    categories=category_order, 
    ordered=True)
# Map categories to numeric values
category_map = {category: idx for idx, category in enumerate(category_order)}
ar_df_time_clean_attended['time_numeric'] = ar_df_time_clean_attended['group'].map(category_map)
# Sort DataFrame based on the categorical order
ar_df_time_clean_attended = ar_df_time_clean_attended.sort_values('group')
ar_df_time_clean_attended

# Create scatter plot
plt.figure(figsize=(12,6))
sns.scatterplot(
    data=ar_df_time_clean_attended, 
    x='group', 
    y='count_of_appointments', 
    hue='appointment_status')

# Trend Line
sns.regplot(
    data=ar_df_time_clean_attended,
    x='time_numeric',  # Numeric x-axis for regression
    y='count_of_appointments',
    scatter=False,
    color="red",
    line_kws={"linewidth": 2, "linestyle": "--"})



# Formatting
plt.title("The longer waiting time leads to missed bookings", fontsize=10)
plt.suptitle("Trend of Attended Bookings vs. Time Between Appointment", fontsize=16)
plt.xlabel("Time Between Booking and Appointment", fontsize=12)
plt.ylabel("Number of Appointments", fontsize=12)
plt.xticks(rotation=45)  
plt.grid(True)
plt.legend(title="Appointment Status")
plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)
plt.ylim(0, ar_df_time_clean_attended['count_of_appointments'].max() + 20)
plt.yticks([0, 100000000, 200000000, 300000000, 400000000])
plt.savefig("Utilisation per month.png")

# %%
# Add a column for the day of the week
location_nc['day_of_week'] = location_nc['appointment_date'].dt.day_name()

location_nc_pivot = location_nc.pivot_table(
    values='count_of_appointments',
    index= 'day_of_week',
    aggfunc='sum').reset_index()

location_nc_pivot = location_nc_pivot.sort_values(by='count_of_appointments', ascending=False)
location_nc_pivot
# Out:
#   day_of_week  count_of_appointments
# 5     Tuesday               61806933
# 1      Monday               59695267
# 6   Wednesday               58984265
# 4    Thursday               56976354
# 0      Friday               52394868
# 2    Saturday                5574922
# 3      Sunday                 614161

# %%
# Add a column for the day of the week
location_nc['day_of_week'] = location_nc['appointment_date'].dt.day_name()

location_nc_pivot = location_nc.pivot_table(
    values='count_of_appointments',
    index= 'day_of_week',
    aggfunc='sum').reset_index()

location_nc_pivot = location_nc_pivot.sort_values(by='count_of_appointments', ascending=False)


# Create a bar chart to see which day has the most appointments
plt.figure(figsize=(10,6))
sns.barplot(
    y="count_of_appointments", 
    x="day_of_week", 
    hue="day_of_week", 
    data=location_nc_pivot)

plt.title("Which day of week has more appointments?- Tuesday")
plt.xlabel("Day of week")
plt.ylabel("Total Appointments")
plt.grid(True)
plt.savefig("Which day of week has more appointments.png")
plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)
plt.show()

# %%
# Create a ar dataframe to exclude "Unknown" in appointment mode
ar_mode_clean =  ar[ar['appointment_mode'] != "Unknown"]
ar_mode_clean
# Out:
#        icb_ons_code appointment_month appointment_status hcp_type  \
# 0         E54000034        01/01/2020           Attended       GP
# 1         E54000034        01/01/2020           Attended       GP
# 2         E54000034        01/01/2020           Attended       GP
# 3         E54000034        01/01/2020           Attended       GP
# 4         E54000034        01/01/2020           Attended       GP
# ...             ...               ...                ...      ...
# 596809    E54000050        06/01/2022            Unknown  Unknown
# 596810    E54000050        06/01/2022            Unknown  Unknown
# 596811    E54000050        06/01/2022            Unknown  Unknown
# 596812    E54000050        06/01/2022            Unknown  Unknown
# 596813    E54000050        06/01/2022            Unknown  Unknown
#
#        appointment_mode time_between_book_and_appointment  \
# 0          Face-to-Face                             1 Day
# ...

# %%
# To find which appointment mode has more appointments
# Create a ar dataframe to exclude "Unknown" in appointment mode
ar_mode_clean =  ar[ar['appointment_mode'] != "Unknown"]
ar_mode_clean

#Create a pieplot to show the appointment mode vs appointments
plt.figure(figsize=(10,6))
# Defining colors for the pie chart 
colors = ['pink', 'silver', 'steelblue','blue'] 
  

plt.figure(figsize=(20, 10))  

# Plotting the pie chart for above dataframe 
ar_mode_clean.groupby(['appointment_mode']).count().plot( 
    kind='pie', y='count_of_appointments', autopct='%1.0f%%',textprops={'fontsize': 14}) 


# Formatting
plt.title("The % of appointment mode vs appointments", fontsize=16) 
plt.ylabel("Total Appointments", fontsize=12)
plt.legend(title='Appointment modes', bbox_to_anchor=(1,0.2)) 
plt.subplots_adjust(left=0.5, right=2, top=5, bottom=0.1)
plt.ylabel("")
# Out:
# Text(0, 0.5, '')

# %%
# Create a plot to forecast the appointments based on ar data set with ARIMA
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

ar_2 = ar.copy()

ar_2['appointment_month'] = pd.to_datetime(ar_2['appointment_month'])
ar_2.set_index('appointment_month', inplace=True)

ar_monthly = ar_2['count_of_appointments'].resample('M').sum()
ar_monthly
# Out:
# appointment_month
# 2020-01-31    27199296
# 2020-02-29    24104621
# 2020-03-31    24053468
# 2020-04-30    16007881
# 2020-05-31    16417212
# 2020-06-30    20690805
# 2020-07-31    22491437
# 2020-08-31    20150520
# 2020-09-30    26714255
# 2020-10-31    28301932
# 2020-11-30    25061602
# 2020-12-31    23535936
# 2021-01-31    22492069
# 2021-02-28    22399569
# 2021-03-31    27225424
# 2021-04-30    23879932
# 2021-05-31    23508395
# 2021-06-30    26784182
# 2021-07-31    25739219
# 2021-08-31    23852171
# 2021-09-30    28522501
# 2021-10-31    30303834
# 2021-11-30    30405070
# 2021-12-31    25140776
# 2022-01-31    25635474
# 2022-02-28    25355260
# 2022-03-31    29595038
# 2022-04-30    23913060
# 2022-05-31    27495508
# 2022-06-30    25828078
# Freq: ME, Name: count_of_appointments, dtype: int64

# %%
# Create a plot to forecast the appointments based on ar data set with ARIMA
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

ar_2 = ar.copy()

ar_2['appointment_month'] = pd.to_datetime(ar_2['appointment_month'])
ar_2.set_index('appointment_month', inplace=True)

ar_monthly = ar_2['count_of_appointments'].resample('M').sum()
ar_monthly

model = ARIMA(ar_monthly, order=(1, 1, 1))
model_fit = model.fit()

# Print summary of the model
print(model_fit.summary())

# Plot the forecasts
forecast = model_fit.forecast(steps=6)
plt.figure(figsize=(10, 6))
plt.plot(ar_monthly, label='Original Monthly Appointments')
plt.plot(forecast, label='Forecast', color='orange')
plt.title("The appointments will tend to increase from the forecast", fontsize=10)
plt.suptitle("Monthly Appointments with ARIMA Forecast", fontsize=16)
plt.xlabel('Month and Year')
plt.ylabel('Number of appointments')
plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)
plt.legend()
plt.show()

forecast_values = model_fit.forecast(steps=6)
forecast_values
# Out:
#                                  SARIMAX Results
# ...
# Dep. Variable:     count_of_appointments   No. Observations:                   30
# Model:                    ARIMA(1, 1, 1)   Log Likelihood                -474.439
# Date:                   Mon, 24 Feb 2025   AIC                            954.878
# Time:                           13:22:24   BIC                            958.979
# Sample:                       01-31-2020   HQIC                           956.162
#                             - 06-30-2022
# Covariance Type:                     opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.4267      0.247      1.724      0.085      -0.058       0.912
# ma.L1         -0.7009      0.192     -3.647      0.000      -1.078      -0.324
# sigma2      7.935e+12   1.11e-14   7.12e+26      0.000    7.93e+12    7.93e+12
# ...
